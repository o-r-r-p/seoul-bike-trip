# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb
import sys
from pathlib import Path
import pickle

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()

test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
X, y = train.to_pandas().iloc[:, 1:], train.to_pandas()["Duration"]

kf = KFold(n_splits=5, shuffle=True, random_state=42)
# XGBoostのパラメータ設定
params = {
    'boosting_type': 'gbtree',
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'eta': 0.01,
    'gamma': 0,
    'max_depth': 7,
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'vervose': 0
}

y_test = test.to_pandas()["Duration"]
X_test = test.to_pandas().iloc[:, 1:]

rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    dtrain = xgb.DMatrix(X.loc[train_index], label=y.loc[train_index], feature_names=train.columns[1:])
    dvalid = xgb.DMatrix(X.loc[val_index], label=y.loc[val_index], feature_names=train.columns[1:])
    dtest = xgb.DMatrix(X_test, label=y_test, feature_names=test.columns[1:])
    # 学習の経過を保存する箱
    print(f"KFold: {i+1} Start")
    evaluation_results = {}
    evals = [(dtrain, 'train'), (dvalid, 'eval')]
    model = xgb.train(params,
                      dtrain,
                      num_boost_round=2000,
                      evals=evals,
                      evals_result=evaluation_results,
                      early_stopping_rounds=50,
                      verbose_eval=50
                     )
    best_iteration = int(model.attributes()['best_iteration'])
    # XGBoost推論
    y_pred = model.predict(dtest, iteration_range=(0, best_iteration + 1))

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/baseline_xgb/model_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# [0]	train-rmse:24.87463	eval-rmse:24.85891
# [50]	train-rmse:18.70457	eval-rmse:18.69341
# [100]	train-rmse:15.75924	eval-rmse:15.75382
# [150]	train-rmse:14.41965	eval-rmse:14.41906
# [200]	train-rmse:13.75879	eval-rmse:13.76129
# [250]	train-rmse:13.33389	eval-rmse:13.33970
# [300]	train-rmse:12.87086	eval-rmse:12.87951
# [350]	train-rmse:12.23884	eval-rmse:12.24889
# [400]	train-rmse:11.64814	eval-rmse:11.65883
# [450]	train-rmse:11.05805	eval-rmse:11.07023
# [500]	train-rmse:10.58793	eval-rmse:10.60286
# [550]	train-rmse:10.20794	eval-rmse:10.22600
# [600]	train-rmse:9.86356	eval-rmse:9.88444
# [650]	train-rmse:9.58701	eval-rmse:9.60932
# [700]	train-rmse:9.33846	eval-rmse:9.36185
# [750]	train-rmse:9.11800	eval-rmse:9.14278
# [800]	train-rmse:8.90764	eval-rmse:8.93412
# [850]	train-rmse:8.71981	eval-rmse:8.74836
# [900]	train-rmse:8.53488	eval-rmse:8.56486
# [950]	train-rmse:8.36254	eval-rmse:8.39423
# [1000]	train-rmse:8.20273	eval-rmse:8.23641
# [1050]	train-rmse:8.05729	eval-rmse:8.09302
# [1100]	train-rmse:7.90872	eval-rmse:7.94627
# [1150]	train-rmse:7.77841	eval-rmse:7.81805
# [1200]	train-rmse:7.64562	eval-rmse:7.68698
# [1250]	train-rmse:7.51570	eval-rmse:7.55938
# [1300]	train-rmse:7.38802	eval-rmse:7.43299
# [1350]	train-rmse:7.26492	eval-rmse:7.31134
# [1400]	train-rmse:7.15014	eval-rmse:7.19777
# [1450]	train-rmse:7.05105	eval-rmse:7.10028
# [1500]	train-rmse:6.94769	eval-rmse:6.99809
# [1550]	train-rmse:6.83972	eval-rmse:6.89140
# [1600]	train-rmse:6.73512	eval-rmse:6.78775
# [1650]	train-rmse:6.64359	eval-rmse:6.69716
# [1700]	train-rmse:6.55191	eval-rmse:6.60618
# [1750]	train-rmse:6.46541	eval-rmse:6.52110
# [1800]	train-rmse:6.37990	eval-rmse:6.43676
# [1850]	train-rmse:6.29408	eval-rmse:6.35247
# [1900]	train-rmse:6.21523	eval-rmse:6.27480
# [1950]	train-rmse:6.13698	eval-rmse:6.19780
# [1999]	train-rmse:6.06394	eval-rmse:6.12616
# KFold: 1 ==> RMSE: 6.1418
# KFold: 2 Start
# [0]	train-rmse:24.87031	eval-rmse:24.87700
# [50]	train-rmse:18.70298	eval-rmse:18.70974
# [100]	train-rmse:15.75904	eval-rmse:15.76710
# [150]	train-rmse:14.41821	eval-rmse:14.42833
# [200]	train-rmse:13.75505	eval-rmse:13.76714
# [250]	train-rmse:13.30933	eval-rmse:13.32317
# [300]	train-rmse:12.85883	eval-rmse:12.87214
# [350]	train-rmse:12.19874	eval-rmse:12.21426
# [400]	train-rmse:11.57538	eval-rmse:11.59522
# [450]	train-rmse:11.01481	eval-rmse:11.03712
# [500]	train-rmse:10.55856	eval-rmse:10.58193
# [550]	train-rmse:10.17784	eval-rmse:10.20215
# [600]	train-rmse:9.86672	eval-rmse:9.89150
# [650]	train-rmse:9.59350	eval-rmse:9.61964
# [700]	train-rmse:9.35002	eval-rmse:9.37804
# [750]	train-rmse:9.13044	eval-rmse:9.15988
# [800]	train-rmse:8.91991	eval-rmse:8.95031
# [850]	train-rmse:8.72733	eval-rmse:8.75868
# [900]	train-rmse:8.54546	eval-rmse:8.57711
# [950]	train-rmse:8.37975	eval-rmse:8.41169
# [1000]	train-rmse:8.21781	eval-rmse:8.25017
# [1050]	train-rmse:8.06328	eval-rmse:8.09628
# [1100]	train-rmse:7.91186	eval-rmse:7.94527
# [1150]	train-rmse:7.77211	eval-rmse:7.80642
# [1200]	train-rmse:7.64814	eval-rmse:7.68302
# [1250]	train-rmse:7.50971	eval-rmse:7.54432
# [1300]	train-rmse:7.38603	eval-rmse:7.42073
# [1350]	train-rmse:7.27099	eval-rmse:7.30546
# [1400]	train-rmse:7.16114	eval-rmse:7.19577
# [1450]	train-rmse:7.04906	eval-rmse:7.08384
# [1500]	train-rmse:6.94501	eval-rmse:6.98029
# [1550]	train-rmse:6.84424	eval-rmse:6.87998
# [1600]	train-rmse:6.74168	eval-rmse:6.77803
# [1650]	train-rmse:6.64497	eval-rmse:6.68174
# [1700]	train-rmse:6.55337	eval-rmse:6.59091
# [1750]	train-rmse:6.46185	eval-rmse:6.49992
# [1800]	train-rmse:6.37986	eval-rmse:6.41891
# [1850]	train-rmse:6.29153	eval-rmse:6.33180
# [1900]	train-rmse:6.21452	eval-rmse:6.25584
# [1950]	train-rmse:6.12641	eval-rmse:6.16894
# [1999]	train-rmse:6.04728	eval-rmse:6.09061
# KFold: 2 ==> RMSE: 6.1208
# KFold: 3 Start
# [0]	train-rmse:24.87906	eval-rmse:24.84186
# [50]	train-rmse:18.70994	eval-rmse:18.67475
# [100]	train-rmse:15.76822	eval-rmse:15.73392
# [150]	train-rmse:14.43017	eval-rmse:14.39544
# [200]	train-rmse:13.76354	eval-rmse:13.72896
# [250]	train-rmse:13.32035	eval-rmse:13.28562
# [300]	train-rmse:12.85408	eval-rmse:12.82105
# [350]	train-rmse:12.21845	eval-rmse:12.18937
# [400]	train-rmse:11.62453	eval-rmse:11.59930
# [450]	train-rmse:11.05486	eval-rmse:11.03646
# [500]	train-rmse:10.58637	eval-rmse:10.57394
# [550]	train-rmse:10.19504	eval-rmse:10.18684
# [600]	train-rmse:9.87849	eval-rmse:9.87400
# [650]	train-rmse:9.60907	eval-rmse:9.60746
# [700]	train-rmse:9.38099	eval-rmse:9.38085
# [750]	train-rmse:9.14540	eval-rmse:9.14780
# [800]	train-rmse:8.93288	eval-rmse:8.93780
# [850]	train-rmse:8.75017	eval-rmse:8.75733
# [900]	train-rmse:8.57496	eval-rmse:8.58395
# [950]	train-rmse:8.38943	eval-rmse:8.39996
# [1000]	train-rmse:8.23640	eval-rmse:8.24863
# [1050]	train-rmse:8.07510	eval-rmse:8.08859
# [1100]	train-rmse:7.94840	eval-rmse:7.96315
# [1150]	train-rmse:7.80315	eval-rmse:7.81972
# [1200]	train-rmse:7.67014	eval-rmse:7.68822
# [1250]	train-rmse:7.53254	eval-rmse:7.55222
# [1300]	train-rmse:7.41493	eval-rmse:7.43569
# [1350]	train-rmse:7.30007	eval-rmse:7.32249
# [1400]	train-rmse:7.19145	eval-rmse:7.21530
# [1450]	train-rmse:7.08289	eval-rmse:7.10789
# [1500]	train-rmse:6.98344	eval-rmse:7.01003
# [1550]	train-rmse:6.87765	eval-rmse:6.90552
# [1600]	train-rmse:6.77943	eval-rmse:6.80874
# [1650]	train-rmse:6.68009	eval-rmse:6.71043
# [1700]	train-rmse:6.59241	eval-rmse:6.62348
# [1750]	train-rmse:6.49709	eval-rmse:6.52875
# [1800]	train-rmse:6.40560	eval-rmse:6.43823
# [1850]	train-rmse:6.31825	eval-rmse:6.35138
# [1900]	train-rmse:6.23168	eval-rmse:6.26598
# [1950]	train-rmse:6.15251	eval-rmse:6.18801
# [1999]	train-rmse:6.07548	eval-rmse:6.11202
# KFold: 3 ==> RMSE: 6.1506
# KFold: 4 Start
# [0]	train-rmse:24.86711	eval-rmse:24.88968
# [50]	train-rmse:18.70018	eval-rmse:18.72184
# [100]	train-rmse:15.75782	eval-rmse:15.77935
# [150]	train-rmse:14.41815	eval-rmse:14.43967
# [200]	train-rmse:13.74954	eval-rmse:13.77100
# [250]	train-rmse:13.31634	eval-rmse:13.34003
# [300]	train-rmse:12.82900	eval-rmse:12.85304
# [350]	train-rmse:12.19678	eval-rmse:12.22252
# [400]	train-rmse:11.59260	eval-rmse:11.61912
# [450]	train-rmse:11.03928	eval-rmse:11.06642
# [500]	train-rmse:10.57390	eval-rmse:10.60189
# [550]	train-rmse:10.18266	eval-rmse:10.21252
# [600]	train-rmse:9.86854	eval-rmse:9.90029
# [650]	train-rmse:9.61520	eval-rmse:9.64928
# [700]	train-rmse:9.38779	eval-rmse:9.42266
# [750]	train-rmse:9.17020	eval-rmse:9.20592
# [800]	train-rmse:8.97449	eval-rmse:9.01082
# [850]	train-rmse:8.79545	eval-rmse:8.83255
# [900]	train-rmse:8.60321	eval-rmse:8.64091
# [950]	train-rmse:8.43887	eval-rmse:8.47769
# [1000]	train-rmse:8.29659	eval-rmse:8.33670
# [1050]	train-rmse:8.12631	eval-rmse:8.16729
# [1100]	train-rmse:7.97342	eval-rmse:8.01583
# [1150]	train-rmse:7.84097	eval-rmse:7.88474
# [1200]	train-rmse:7.69962	eval-rmse:7.74454
# [1250]	train-rmse:7.56585	eval-rmse:7.61155
# [1300]	train-rmse:7.44705	eval-rmse:7.49396
# [1350]	train-rmse:7.32419	eval-rmse:7.37236
# [1400]	train-rmse:7.21108	eval-rmse:7.26013
# [1450]	train-rmse:7.09811	eval-rmse:7.14879
# [1500]	train-rmse:6.98827	eval-rmse:7.03982
# [1550]	train-rmse:6.88237	eval-rmse:6.93454
# [1600]	train-rmse:6.77595	eval-rmse:6.82866
# [1650]	train-rmse:6.67799	eval-rmse:6.73143
# [1700]	train-rmse:6.59009	eval-rmse:6.64414
# [1750]	train-rmse:6.50542	eval-rmse:6.56036
# [1800]	train-rmse:6.41789	eval-rmse:6.47363
# [1850]	train-rmse:6.34098	eval-rmse:6.39764
# [1900]	train-rmse:6.25888	eval-rmse:6.31654
# [1950]	train-rmse:6.18361	eval-rmse:6.24215
# [1999]	train-rmse:6.11173	eval-rmse:6.17112
# KFold: 4 ==> RMSE: 6.1867
# KFold: 5 Start
# [0]	train-rmse:24.86683	eval-rmse:24.89062
# [50]	train-rmse:18.69823	eval-rmse:18.72724
# [100]	train-rmse:15.75744	eval-rmse:15.79243
# [150]	train-rmse:14.41387	eval-rmse:14.45572
# [200]	train-rmse:13.74726	eval-rmse:13.79400
# [250]	train-rmse:13.31816	eval-rmse:13.36772
# [300]	train-rmse:12.84983	eval-rmse:12.90228
# [350]	train-rmse:12.15262	eval-rmse:12.20465
# [400]	train-rmse:11.57924	eval-rmse:11.63130
# [450]	train-rmse:11.02762	eval-rmse:11.07878
# [500]	train-rmse:10.55883	eval-rmse:10.60907
# [550]	train-rmse:10.18033	eval-rmse:10.22969
# [600]	train-rmse:9.85939	eval-rmse:9.90904
# [650]	train-rmse:9.58997	eval-rmse:9.64007
# [700]	train-rmse:9.33635	eval-rmse:9.38744
# [750]	train-rmse:9.12676	eval-rmse:9.17958
# [800]	train-rmse:8.93792	eval-rmse:8.99200
# [850]	train-rmse:8.74449	eval-rmse:8.79944
# [900]	train-rmse:8.55652	eval-rmse:8.61230
# [950]	train-rmse:8.37678	eval-rmse:8.43341
# [1000]	train-rmse:8.20552	eval-rmse:8.26285
# [1050]	train-rmse:8.04299	eval-rmse:8.10113
# [1100]	train-rmse:7.89475	eval-rmse:7.95381
# [1150]	train-rmse:7.74490	eval-rmse:7.80513
# [1200]	train-rmse:7.61316	eval-rmse:7.67428
# [1250]	train-rmse:7.49324	eval-rmse:7.55540
# [1300]	train-rmse:7.37020	eval-rmse:7.43309
# [1350]	train-rmse:7.24912	eval-rmse:7.31312
# [1400]	train-rmse:7.15227	eval-rmse:7.21692
# [1450]	train-rmse:7.03879	eval-rmse:7.10426
# [1500]	train-rmse:6.93387	eval-rmse:6.99998
# [1550]	train-rmse:6.84547	eval-rmse:6.91212
# [1600]	train-rmse:6.73830	eval-rmse:6.80602
# [1650]	train-rmse:6.64381	eval-rmse:6.71228
# [1700]	train-rmse:6.55275	eval-rmse:6.62178
# [1750]	train-rmse:6.47057	eval-rmse:6.54043
# [1800]	train-rmse:6.38381	eval-rmse:6.45433
# [1850]	train-rmse:6.28844	eval-rmse:6.35980
# [1900]	train-rmse:6.20350	eval-rmse:6.27586
# [1950]	train-rmse:6.12302	eval-rmse:6.19604
# [1999]	train-rmse:6.04944	eval-rmse:6.12387
# KFold: 5 ==> RMSE: 6.1286
# Average RMSE: 6.1457 ± 0.0229
