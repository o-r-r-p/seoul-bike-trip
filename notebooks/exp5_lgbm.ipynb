# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')
import pickle

import lightgbm as lgb
import sys
from pathlib import Path

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering, feature_agg_temp

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()
test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
train = feature_engineering(train).to_pandas()
test = feature_engineering(test).to_pandas()

# %%
train, test = feature_agg_temp(train, test)

# %%
train.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0        28      8480  37.530167  127.007439  37.535221  127.068398
# 1        51      7710  37.530167  127.007439  37.535221  127.068398
# 2        59      8020  37.530167  127.007439  37.535221  127.068398
# 3        53     10490  37.530167  127.007439  37.535221  127.068398
# 4        24      7230  37.530167  127.007439  37.535221  127.068398
#
#    Haversine  Pmonth  Pday  Phour  ...  Snow  GroundTemp  Dust  Usage_time  \
# 0   5.404561       4    14     19  ...   0.0         9.9  13.0          28
# 1   5.404561       9    12     18  ...   0.0        28.5  17.0          51
# 2   5.404561       6    30     22  ...   0.0        22.4   0.0          60
# 3   5.404561       7    25     22  ...   0.0        28.1  27.0          55
# 4   5.404561      11    30     20  ...   0.0        -0.4  50.0          26
#
#      Velocity  Temp_max  Temp_min  Temp_mean  Duration_meadian  Duratioin_mean
# 0  302.857143      22.9       2.5  16.548405              51.0            43.0
# 1  151.176471      28.8      18.3  24.362245              51.0            43.0
# 2  133.666667      27.4      19.0  22.198692              51.0            43.0
# 3  190.727273      32.5      20.4  27.672861              51.0            43.0
# 4  278.076923      13.9       2.6   8.890479              51.0            43.0
#
# [5 rows x 32 columns]

# %%
# データの準備
X, y = train.iloc[:, 1:], train["Duration"]
X_test = test.iloc[:, 1:]
y_test = test["Duration"]

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt', # LightGBMでは 'gbdt' が通常の勾配ブースティングを表す
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'lambda_l2': 0.2,
    'max_depth': 7,
    'num_leaves': 64, # LightGBM特有のパラメータ、ツリーの葉の数
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'verbose': -1 # verboseの設定は -1, 0, 1 となります
}

# KFoldの設定
kf = KFold(n_splits=5, shuffle=True, random_state=42)

del train, test

# %%
# Usage_timeを追加しての検証
rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # LightGBM用データセットの作成
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    print(f"KFold: {i+1} Start")
    
    # モデル学習
    model = lgb.train(params,
                      lgb_train,
                      num_boost_round=2000,
                      valid_sets=[lgb_train, lgb_val],
                      early_stopping_rounds=50,
                      verbose_eval=100
                     )
    
    # 推論
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/exp_lgbm/model_velocity_2000_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32951	valid_1's rmse: 9.31889
# [200]	training's rmse: 3.78685	valid_1's rmse: 3.77788
# [300]	training's rmse: 2.10364	valid_1's rmse: 2.09467
# [400]	training's rmse: 1.72362	valid_1's rmse: 1.71731
# [500]	training's rmse: 1.62976	valid_1's rmse: 1.62726
# [600]	training's rmse: 1.58604	valid_1's rmse: 1.58814
# [700]	training's rmse: 1.552	valid_1's rmse: 1.56064
# [800]	training's rmse: 1.5277	valid_1's rmse: 1.54211
# [900]	training's rmse: 1.50778	valid_1's rmse: 1.52602
# [1000]	training's rmse: 1.49566	valid_1's rmse: 1.51742
# [1100]	training's rmse: 1.48468	valid_1's rmse: 1.50907
# [1200]	training's rmse: 1.4725	valid_1's rmse: 1.50019
# [1300]	training's rmse: 1.46235	valid_1's rmse: 1.49315
# [1400]	training's rmse: 1.45182	valid_1's rmse: 1.48566
# [1500]	training's rmse: 1.43947	valid_1's rmse: 1.47578
# [1600]	training's rmse: 1.42851	valid_1's rmse: 1.46808
# [1700]	training's rmse: 1.41919	valid_1's rmse: 1.46174
# [1800]	training's rmse: 1.41141	valid_1's rmse: 1.4568
# [1900]	training's rmse: 1.40268	valid_1's rmse: 1.45064
# [2000]	training's rmse: 1.39591	valid_1's rmse: 1.44642
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.39591	valid_1's rmse: 1.44642
# KFold: 1 ==> RMSE: 1.4508
# KFold: 2 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.3268	valid_1's rmse: 9.33425
# [200]	training's rmse: 3.78317	valid_1's rmse: 3.79657
# [300]	training's rmse: 2.09783	valid_1's rmse: 2.12509
# [400]	training's rmse: 1.71526	valid_1's rmse: 1.75453
# [500]	training's rmse: 1.6213	valid_1's rmse: 1.66651
# [600]	training's rmse: 1.57681	valid_1's rmse: 1.62624
# [700]	training's rmse: 1.53959	valid_1's rmse: 1.59628
# [800]	training's rmse: 1.51156	valid_1's rmse: 1.57424
# [900]	training's rmse: 1.49259	valid_1's rmse: 1.55991
# [1000]	training's rmse: 1.48028	valid_1's rmse: 1.55153
# [1100]	training's rmse: 1.46853	valid_1's rmse: 1.54298
# [1200]	training's rmse: 1.45792	valid_1's rmse: 1.5355
# [1300]	training's rmse: 1.44848	valid_1's rmse: 1.52891
# [1400]	training's rmse: 1.44006	valid_1's rmse: 1.52345
# [1500]	training's rmse: 1.43126	valid_1's rmse: 1.51696
# [1600]	training's rmse: 1.42342	valid_1's rmse: 1.51158
# [1700]	training's rmse: 1.41666	valid_1's rmse: 1.50751
# [1800]	training's rmse: 1.40971	valid_1's rmse: 1.50314
# [1900]	training's rmse: 1.40325	valid_1's rmse: 1.49876
# [2000]	training's rmse: 1.39693	valid_1's rmse: 1.49464
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.39693	valid_1's rmse: 1.49464
# KFold: 2 ==> RMSE: 1.4577
# KFold: 3 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33062	valid_1's rmse: 9.32232
# [200]	training's rmse: 3.78808	valid_1's rmse: 3.78386
# [300]	training's rmse: 2.10497	valid_1's rmse: 2.1036
# [400]	training's rmse: 1.72409	valid_1's rmse: 1.72721
# [500]	training's rmse: 1.62731	valid_1's rmse: 1.63849
# [600]	training's rmse: 1.58242	valid_1's rmse: 1.59787
# [700]	training's rmse: 1.54818	valid_1's rmse: 1.57067
# [800]	training's rmse: 1.5228	valid_1's rmse: 1.5525
# [900]	training's rmse: 1.50373	valid_1's rmse: 1.53786
# [1000]	training's rmse: 1.49088	valid_1's rmse: 1.52815
# [1100]	training's rmse: 1.47852	valid_1's rmse: 1.51863
# [1200]	training's rmse: 1.46894	valid_1's rmse: 1.51202
# [1300]	training's rmse: 1.45768	valid_1's rmse: 1.50416
# [1400]	training's rmse: 1.44748	valid_1's rmse: 1.49691
# [1500]	training's rmse: 1.43798	valid_1's rmse: 1.4902
# [1600]	training's rmse: 1.43043	valid_1's rmse: 1.48551
# [1700]	training's rmse: 1.4229	valid_1's rmse: 1.48036
# [1800]	training's rmse: 1.41572	valid_1's rmse: 1.47567
# [1900]	training's rmse: 1.40651	valid_1's rmse: 1.46929
# [2000]	training's rmse: 1.39864	valid_1's rmse: 1.46415
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.39864	valid_1's rmse: 1.46415
# KFold: 3 ==> RMSE: 1.4574
# KFold: 4 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32779	valid_1's rmse: 9.33599
# [200]	training's rmse: 3.78504	valid_1's rmse: 3.79461
# [300]	training's rmse: 2.10128	valid_1's rmse: 2.11816
# [400]	training's rmse: 1.7184	valid_1's rmse: 1.74368
# [500]	training's rmse: 1.62553	valid_1's rmse: 1.65598
# [600]	training's rmse: 1.58002	valid_1's rmse: 1.61575
# [700]	training's rmse: 1.54551	valid_1's rmse: 1.58967
# [800]	training's rmse: 1.52145	valid_1's rmse: 1.5712
# [900]	training's rmse: 1.50427	valid_1's rmse: 1.55818
# [1000]	training's rmse: 1.4928	valid_1's rmse: 1.54986
# [1100]	training's rmse: 1.48266	valid_1's rmse: 1.54256
# [1200]	training's rmse: 1.47215	valid_1's rmse: 1.53556
# [1300]	training's rmse: 1.45919	valid_1's rmse: 1.52633
# [1400]	training's rmse: 1.44726	valid_1's rmse: 1.51714
# [1500]	training's rmse: 1.43797	valid_1's rmse: 1.51078
# [1600]	training's rmse: 1.42973	valid_1's rmse: 1.50512
# [1700]	training's rmse: 1.4218	valid_1's rmse: 1.49934
# [1800]	training's rmse: 1.41546	valid_1's rmse: 1.49504
# [1900]	training's rmse: 1.40804	valid_1's rmse: 1.48912
# [2000]	training's rmse: 1.40253	valid_1's rmse: 1.48547
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.40253	valid_1's rmse: 1.48547
# KFold: 4 ==> RMSE: 1.4635
# KFold: 5 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32836	valid_1's rmse: 9.33593
# [200]	training's rmse: 3.78673	valid_1's rmse: 3.79483
# [300]	training's rmse: 2.10393	valid_1's rmse: 2.11703
# [400]	training's rmse: 1.72423	valid_1's rmse: 1.74242
# [500]	training's rmse: 1.62864	valid_1's rmse: 1.65386
# [600]	training's rmse: 1.58422	valid_1's rmse: 1.61449
# [700]	training's rmse: 1.55222	valid_1's rmse: 1.59071
# [800]	training's rmse: 1.52486	valid_1's rmse: 1.57014
# [900]	training's rmse: 1.5057	valid_1's rmse: 1.55647
# [1000]	training's rmse: 1.49365	valid_1's rmse: 1.54906
# [1100]	training's rmse: 1.48288	valid_1's rmse: 1.5418
# [1200]	training's rmse: 1.47198	valid_1's rmse: 1.53372
# [1300]	training's rmse: 1.4613	valid_1's rmse: 1.52507
# [1400]	training's rmse: 1.45175	valid_1's rmse: 1.51759
# [1500]	training's rmse: 1.4423	valid_1's rmse: 1.51005
# [1600]	training's rmse: 1.43423	valid_1's rmse: 1.50402
# [1700]	training's rmse: 1.42563	valid_1's rmse: 1.4976
# [1800]	training's rmse: 1.41787	valid_1's rmse: 1.4922
# [1900]	training's rmse: 1.4111	valid_1's rmse: 1.48768
# [2000]	training's rmse: 1.40345	valid_1's rmse: 1.48225
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.40345	valid_1's rmse: 1.48225
# KFold: 5 ==> RMSE: 1.4701
# Average RMSE: 1.4599 ± 0.0065
