# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')
import pickle

import lightgbm as lgb
import sys
from pathlib import Path

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering, feature_agg_temp

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()
test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
train = feature_engineering(train).to_pandas()
test = feature_engineering(test).to_pandas()

# %%
train, test = feature_agg_temp(train, test)

# %%
train.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0        28      8480  37.530167  127.007439  37.535221  127.068398
# 1        51      7710  37.530167  127.007439  37.535221  127.068398
# 2        59      8020  37.530167  127.007439  37.535221  127.068398
# 3        53     10490  37.530167  127.007439  37.535221  127.068398
# 4        24      7230  37.530167  127.007439  37.535221  127.068398
#
#    Haversine  Pmonth  Pday  Phour  ...  Snow  GroundTemp  Dust  Usage_time  \
# 0   5.404561       4    14     19  ...   0.0         9.9  13.0          28
# 1   5.404561       9    12     18  ...   0.0        28.5  17.0          51
# 2   5.404561       6    30     22  ...   0.0        22.4   0.0          60
# 3   5.404561       7    25     22  ...   0.0        28.1  27.0          55
# 4   5.404561      11    30     20  ...   0.0        -0.4  50.0          26
#
#      Velocity  Temp_mean  Temp_min  Temp_max  Duratioin_mean  Duration_meadian
# 0  302.857143  16.548405       2.5      22.9            43.0              51.0
# 1  151.176471  24.362245      18.3      28.8            43.0              51.0
# 2  133.666667  22.198692      19.0      27.4            43.0              51.0
# 3  190.727273  27.672861      20.4      32.5            43.0              51.0
# 4  278.076923   8.890479       2.6      13.9            43.0              51.0
#
# [5 rows x 32 columns]

# %%
# データの準備
X, y = train.iloc[:, 1:], train["Duration"]
X_test = test.iloc[:, 1:]
y_test = test["Duration"]

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt', # LightGBMでは 'gbdt' が通常の勾配ブースティングを表す
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'lambda_l2': 0.2,
    'max_depth': 7,
    'num_leaves': 64, # LightGBM特有のパラメータ、ツリーの葉の数
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'verbose': -1 # verboseの設定は -1, 0, 1 となります
}

# KFoldの設定
kf = KFold(n_splits=4, shuffle=True, random_state=42)

del train, test

# %%
# Usage_timeを追加しての検証
rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # LightGBM用データセットの作成
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    print(f"KFold: {i+1} Start")
    
    # モデル学習
    model = lgb.train(params,
                      lgb_train,
                      num_boost_round=5000,
                      valid_sets=[lgb_train, lgb_val],
                      early_stopping_rounds=50,
                      verbose_eval=100
                     )
    
    # 推論
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/exp_lgbm/model_5000_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33043	valid_1's rmse: 9.32229
# [200]	training's rmse: 3.78801	valid_1's rmse: 3.78736
# [300]	training's rmse: 2.104	valid_1's rmse: 2.1109
# [400]	training's rmse: 1.72328	valid_1's rmse: 1.737
# [500]	training's rmse: 1.63153	valid_1's rmse: 1.64985
# [600]	training's rmse: 1.58636	valid_1's rmse: 1.60923
# [700]	training's rmse: 1.55004	valid_1's rmse: 1.57952
# [800]	training's rmse: 1.52055	valid_1's rmse: 1.5549
# [900]	training's rmse: 1.50231	valid_1's rmse: 1.54038
# [1000]	training's rmse: 1.48905	valid_1's rmse: 1.53099
# [1100]	training's rmse: 1.47799	valid_1's rmse: 1.52325
# [1200]	training's rmse: 1.46797	valid_1's rmse: 1.51651
# [1300]	training's rmse: 1.45669	valid_1's rmse: 1.50825
# [1400]	training's rmse: 1.44507	valid_1's rmse: 1.4993
# [1500]	training's rmse: 1.43534	valid_1's rmse: 1.49183
# [1600]	training's rmse: 1.42673	valid_1's rmse: 1.48594
# [1700]	training's rmse: 1.41958	valid_1's rmse: 1.48152
# [1800]	training's rmse: 1.41152	valid_1's rmse: 1.47603
# [1900]	training's rmse: 1.40516	valid_1's rmse: 1.47242
# [2000]	training's rmse: 1.39848	valid_1's rmse: 1.46813
# [2100]	training's rmse: 1.39111	valid_1's rmse: 1.46288
# [2200]	training's rmse: 1.38498	valid_1's rmse: 1.45915
# [2300]	training's rmse: 1.37856	valid_1's rmse: 1.45468
# [2400]	training's rmse: 1.37302	valid_1's rmse: 1.45101
# [2500]	training's rmse: 1.36722	valid_1's rmse: 1.4478
# [2600]	training's rmse: 1.36204	valid_1's rmse: 1.44472
# [2700]	training's rmse: 1.35689	valid_1's rmse: 1.44123
# [2800]	training's rmse: 1.35179	valid_1's rmse: 1.43795
# [2900]	training's rmse: 1.34568	valid_1's rmse: 1.43384
# [3000]	training's rmse: 1.34081	valid_1's rmse: 1.43078
# [3100]	training's rmse: 1.33663	valid_1's rmse: 1.42834
# [3200]	training's rmse: 1.33267	valid_1's rmse: 1.42587
# [3300]	training's rmse: 1.32904	valid_1's rmse: 1.42362
# [3400]	training's rmse: 1.3245	valid_1's rmse: 1.42061
# [3500]	training's rmse: 1.32104	valid_1's rmse: 1.41857
# [3600]	training's rmse: 1.31798	valid_1's rmse: 1.41676
# [3700]	training's rmse: 1.31514	valid_1's rmse: 1.41513
# [3800]	training's rmse: 1.3121	valid_1's rmse: 1.41322
# [3900]	training's rmse: 1.3097	valid_1's rmse: 1.41206
# [4000]	training's rmse: 1.30725	valid_1's rmse: 1.41078
# [4100]	training's rmse: 1.30515	valid_1's rmse: 1.4096
# [4200]	training's rmse: 1.30283	valid_1's rmse: 1.40833
# [4300]	training's rmse: 1.29998	valid_1's rmse: 1.40672
# [4400]	training's rmse: 1.29753	valid_1's rmse: 1.40529
# [4500]	training's rmse: 1.29548	valid_1's rmse: 1.40431
# [4600]	training's rmse: 1.29293	valid_1's rmse: 1.40288
# [4700]	training's rmse: 1.29042	valid_1's rmse: 1.40149
# [4800]	training's rmse: 1.2877	valid_1's rmse: 1.40009
# [4900]	training's rmse: 1.28567	valid_1's rmse: 1.39905
# [5000]	training's rmse: 1.2838	valid_1's rmse: 1.39816
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 1.2838	valid_1's rmse: 1.39816
# KFold: 1 ==> RMSE: 1.4012
# KFold: 2 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32675	valid_1's rmse: 9.33411
# [200]	training's rmse: 3.7858	valid_1's rmse: 3.7877
# [300]	training's rmse: 2.10121	valid_1's rmse: 2.10523
# [400]	training's rmse: 1.71921	valid_1's rmse: 1.72971
# [500]	training's rmse: 1.62455	valid_1's rmse: 1.64123
# [600]	training's rmse: 1.57857	valid_1's rmse: 1.59996
# [700]	training's rmse: 1.5441	valid_1's rmse: 1.57344
# [800]	training's rmse: 1.51596	valid_1's rmse: 1.55183
# [900]	training's rmse: 1.50029	valid_1's rmse: 1.54048
# [1000]	training's rmse: 1.4878	valid_1's rmse: 1.53189
# [1100]	training's rmse: 1.47855	valid_1's rmse: 1.52618
# [1200]	training's rmse: 1.46881	valid_1's rmse: 1.51974
# [1300]	training's rmse: 1.45735	valid_1's rmse: 1.51253
# [1400]	training's rmse: 1.44756	valid_1's rmse: 1.50572
# [1500]	training's rmse: 1.4378	valid_1's rmse: 1.4995
# [1600]	training's rmse: 1.43085	valid_1's rmse: 1.49532
# [1700]	training's rmse: 1.42255	valid_1's rmse: 1.49
# [1800]	training's rmse: 1.41567	valid_1's rmse: 1.48567
# [1900]	training's rmse: 1.40936	valid_1's rmse: 1.4822
# [2000]	training's rmse: 1.40403	valid_1's rmse: 1.47887
# [2100]	training's rmse: 1.39664	valid_1's rmse: 1.47373
# [2200]	training's rmse: 1.38969	valid_1's rmse: 1.46902
# [2300]	training's rmse: 1.38292	valid_1's rmse: 1.465
# [2400]	training's rmse: 1.37696	valid_1's rmse: 1.46141
# [2500]	training's rmse: 1.37173	valid_1's rmse: 1.45802
# [2600]	training's rmse: 1.36722	valid_1's rmse: 1.45552
# [2700]	training's rmse: 1.3624	valid_1's rmse: 1.45243
# [2800]	training's rmse: 1.35829	valid_1's rmse: 1.45005
# [2900]	training's rmse: 1.35305	valid_1's rmse: 1.44702
# [3000]	training's rmse: 1.34857	valid_1's rmse: 1.44463
# [3100]	training's rmse: 1.34461	valid_1's rmse: 1.44234
# [3200]	training's rmse: 1.34084	valid_1's rmse: 1.43993
# [3300]	training's rmse: 1.33615	valid_1's rmse: 1.43698
# [3400]	training's rmse: 1.33203	valid_1's rmse: 1.43439
# [3500]	training's rmse: 1.32806	valid_1's rmse: 1.4319
# [3600]	training's rmse: 1.32386	valid_1's rmse: 1.42925
# [3700]	training's rmse: 1.32096	valid_1's rmse: 1.42783
# [3800]	training's rmse: 1.31714	valid_1's rmse: 1.42569
# [3900]	training's rmse: 1.31417	valid_1's rmse: 1.42412
# [4000]	training's rmse: 1.31107	valid_1's rmse: 1.42257
# [4100]	training's rmse: 1.30796	valid_1's rmse: 1.42113
# [4200]	training's rmse: 1.30492	valid_1's rmse: 1.41999
# [4300]	training's rmse: 1.30237	valid_1's rmse: 1.41856
# [4400]	training's rmse: 1.30008	valid_1's rmse: 1.4176
# [4500]	training's rmse: 1.29785	valid_1's rmse: 1.41662
# [4600]	training's rmse: 1.29559	valid_1's rmse: 1.41543
# [4700]	training's rmse: 1.29288	valid_1's rmse: 1.41405
# [4800]	training's rmse: 1.29025	valid_1's rmse: 1.41245
# [4900]	training's rmse: 1.28803	valid_1's rmse: 1.41127
# [5000]	training's rmse: 1.28566	valid_1's rmse: 1.40996
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 1.28566	valid_1's rmse: 1.40996
# KFold: 2 ==> RMSE: 1.4084
# KFold: 3 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33048	valid_1's rmse: 9.32575
# [200]	training's rmse: 3.78792	valid_1's rmse: 3.78943
# [300]	training's rmse: 2.10531	valid_1's rmse: 2.11298
# [400]	training's rmse: 1.72338	valid_1's rmse: 1.73899
# [500]	training's rmse: 1.62872	valid_1's rmse: 1.65164
# [600]	training's rmse: 1.58283	valid_1's rmse: 1.6126
# [700]	training's rmse: 1.54884	valid_1's rmse: 1.58635
# [800]	training's rmse: 1.52192	valid_1's rmse: 1.56537
# [900]	training's rmse: 1.5021	valid_1's rmse: 1.55023
# [1000]	training's rmse: 1.48928	valid_1's rmse: 1.5409
# [1100]	training's rmse: 1.47698	valid_1's rmse: 1.53152
# [1200]	training's rmse: 1.46606	valid_1's rmse: 1.52427
# [1300]	training's rmse: 1.45434	valid_1's rmse: 1.51616
# [1400]	training's rmse: 1.44231	valid_1's rmse: 1.50746
# [1500]	training's rmse: 1.43247	valid_1's rmse: 1.50068
# [1600]	training's rmse: 1.42454	valid_1's rmse: 1.49515
# [1700]	training's rmse: 1.41738	valid_1's rmse: 1.49069
# [1800]	training's rmse: 1.40948	valid_1's rmse: 1.48582
# [1900]	training's rmse: 1.40268	valid_1's rmse: 1.48172
# [2000]	training's rmse: 1.39592	valid_1's rmse: 1.47793
# [2100]	training's rmse: 1.38966	valid_1's rmse: 1.47419
# [2200]	training's rmse: 1.38465	valid_1's rmse: 1.47151
# [2300]	training's rmse: 1.3793	valid_1's rmse: 1.46837
# [2400]	training's rmse: 1.37324	valid_1's rmse: 1.46465
# [2500]	training's rmse: 1.36625	valid_1's rmse: 1.45965
# [2600]	training's rmse: 1.35894	valid_1's rmse: 1.454
# [2700]	training's rmse: 1.3519	valid_1's rmse: 1.44899
# [2800]	training's rmse: 1.3466	valid_1's rmse: 1.44541
# [2900]	training's rmse: 1.34152	valid_1's rmse: 1.44222
# [3000]	training's rmse: 1.33739	valid_1's rmse: 1.43988
# [3100]	training's rmse: 1.33296	valid_1's rmse: 1.4371
# [3200]	training's rmse: 1.329	valid_1's rmse: 1.43474
# [3300]	training's rmse: 1.32496	valid_1's rmse: 1.43239
# [3400]	training's rmse: 1.32146	valid_1's rmse: 1.43017
# [3500]	training's rmse: 1.31798	valid_1's rmse: 1.42814
# [3600]	training's rmse: 1.31477	valid_1's rmse: 1.42632
# [3700]	training's rmse: 1.31159	valid_1's rmse: 1.42459
# [3800]	training's rmse: 1.30883	valid_1's rmse: 1.42318
# [3900]	training's rmse: 1.30628	valid_1's rmse: 1.42198
# [4000]	training's rmse: 1.30371	valid_1's rmse: 1.42055
# [4100]	training's rmse: 1.30179	valid_1's rmse: 1.41941
# [4200]	training's rmse: 1.29907	valid_1's rmse: 1.4177
# [4300]	training's rmse: 1.29624	valid_1's rmse: 1.41598
# [4400]	training's rmse: 1.29353	valid_1's rmse: 1.41446
# [4500]	training's rmse: 1.2913	valid_1's rmse: 1.4132
# [4600]	training's rmse: 1.28906	valid_1's rmse: 1.41212
# [4700]	training's rmse: 1.28674	valid_1's rmse: 1.41083
# [4800]	training's rmse: 1.28434	valid_1's rmse: 1.40941
# [4900]	training's rmse: 1.28188	valid_1's rmse: 1.40828
# [5000]	training's rmse: 1.27956	valid_1's rmse: 1.40699
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 1.27956	valid_1's rmse: 1.40699
# KFold: 3 ==> RMSE: 1.4019
# KFold: 4 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32669	valid_1's rmse: 9.33491
# [200]	training's rmse: 3.78359	valid_1's rmse: 3.79471
# [300]	training's rmse: 2.09828	valid_1's rmse: 2.11788
# [400]	training's rmse: 1.71852	valid_1's rmse: 1.74492
# [500]	training's rmse: 1.62398	valid_1's rmse: 1.65646
# [600]	training's rmse: 1.57896	valid_1's rmse: 1.61663
# [700]	training's rmse: 1.54497	valid_1's rmse: 1.58904
# [800]	training's rmse: 1.51897	valid_1's rmse: 1.57006
# [900]	training's rmse: 1.50081	valid_1's rmse: 1.55649
# [1000]	training's rmse: 1.48746	valid_1's rmse: 1.54735
# [1100]	training's rmse: 1.47435	valid_1's rmse: 1.53769
# [1200]	training's rmse: 1.46326	valid_1's rmse: 1.52966
# [1300]	training's rmse: 1.45164	valid_1's rmse: 1.52087
# [1400]	training's rmse: 1.44156	valid_1's rmse: 1.51343
# [1500]	training's rmse: 1.43132	valid_1's rmse: 1.50575
# [1600]	training's rmse: 1.42287	valid_1's rmse: 1.49957
# [1700]	training's rmse: 1.41582	valid_1's rmse: 1.49487
# [1800]	training's rmse: 1.40856	valid_1's rmse: 1.48989
# [1900]	training's rmse: 1.40193	valid_1's rmse: 1.48557
# [2000]	training's rmse: 1.39391	valid_1's rmse: 1.48008
# [2100]	training's rmse: 1.38635	valid_1's rmse: 1.47486
# [2200]	training's rmse: 1.37919	valid_1's rmse: 1.46986
# [2300]	training's rmse: 1.37349	valid_1's rmse: 1.46621
# [2400]	training's rmse: 1.36846	valid_1's rmse: 1.46292
# [2500]	training's rmse: 1.36348	valid_1's rmse: 1.46004
# [2600]	training's rmse: 1.35805	valid_1's rmse: 1.45666
# [2700]	training's rmse: 1.35343	valid_1's rmse: 1.45367
# [2800]	training's rmse: 1.3484	valid_1's rmse: 1.45046
# [2900]	training's rmse: 1.34306	valid_1's rmse: 1.44696
# [3000]	training's rmse: 1.33813	valid_1's rmse: 1.44367
# [3100]	training's rmse: 1.33311	valid_1's rmse: 1.44051
# [3200]	training's rmse: 1.32895	valid_1's rmse: 1.43833
# [3300]	training's rmse: 1.32471	valid_1's rmse: 1.43565
# [3400]	training's rmse: 1.32033	valid_1's rmse: 1.43271
# [3500]	training's rmse: 1.31642	valid_1's rmse: 1.43023
# [3600]	training's rmse: 1.31318	valid_1's rmse: 1.42838
# [3700]	training's rmse: 1.30979	valid_1's rmse: 1.42621
# [3800]	training's rmse: 1.30657	valid_1's rmse: 1.4242
# [3900]	training's rmse: 1.30346	valid_1's rmse: 1.42218
# [4000]	training's rmse: 1.30033	valid_1's rmse: 1.42007
# [4100]	training's rmse: 1.29692	valid_1's rmse: 1.4177
# [4200]	training's rmse: 1.29391	valid_1's rmse: 1.41565
# [4300]	training's rmse: 1.29107	valid_1's rmse: 1.41401
# [4400]	training's rmse: 1.28873	valid_1's rmse: 1.41261
# [4500]	training's rmse: 1.28595	valid_1's rmse: 1.41093
# [4600]	training's rmse: 1.28392	valid_1's rmse: 1.40991
# [4700]	training's rmse: 1.28156	valid_1's rmse: 1.40837
# [4800]	training's rmse: 1.27927	valid_1's rmse: 1.40703
# [4900]	training's rmse: 1.2769	valid_1's rmse: 1.40547
# [5000]	training's rmse: 1.2751	valid_1's rmse: 1.40438
# Did not meet early stopping. Best iteration is:
# [5000]	training's rmse: 1.2751	valid_1's rmse: 1.40438
# KFold: 4 ==> RMSE: 1.3956
# Average RMSE: 1.4018 ± 0.0045
