# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

import warnings
warnings.filterwarnings('ignore')
import pickle

import lightgbm as lgb
import sys
from pathlib import Path

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()
test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
train = feature_engineering(train).to_pandas()
test = feature_engineering(test).to_pandas()

# %%
# データの準備
X, y = train.iloc[:, 1:], train["Duration"]
X_test = test.iloc[:, 1:]
y_test = test["Duration"]

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt', # LightGBMでは 'gbdt' が通常の勾配ブースティングを表す
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'lambda_l2': 0.2,
    'max_depth': 7,
    'num_leaves': 64, # LightGBM特有のパラメータ、ツリーの葉の数
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'verbose': -1 # verboseの設定は -1, 0, 1 となります
}

# KFoldの設定
kf = KFold(n_splits=5, shuffle=True, random_state=42)

del train, test

# %%
# Usage_timeを追加しての検証
rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # LightGBM用データセットの作成
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    print(f"KFold: {i+1} Start")
    
    # モデル学習
    model = lgb.train(params,
                      lgb_train,
                      num_boost_round=2000,
                      valid_sets=[lgb_train, lgb_val],
                      early_stopping_rounds=50,
                      verbose_eval=100
                     )
    
    # 推論
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/exp_lgbm/model_2000_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.3307	valid_1's rmse: 9.32115
# [200]	training's rmse: 3.79679	valid_1's rmse: 3.78816
# [300]	training's rmse: 2.12925	valid_1's rmse: 2.12096
# [400]	training's rmse: 1.75402	valid_1's rmse: 1.74871
# [500]	training's rmse: 1.6631	valid_1's rmse: 1.66148
# [600]	training's rmse: 1.62059	valid_1's rmse: 1.62222
# [700]	training's rmse: 1.59039	valid_1's rmse: 1.59949
# [800]	training's rmse: 1.56574	valid_1's rmse: 1.58295
# [900]	training's rmse: 1.54755	valid_1's rmse: 1.57186
# [1000]	training's rmse: 1.53173	valid_1's rmse: 1.5609
# [1100]	training's rmse: 1.52069	valid_1's rmse: 1.5534
# [1200]	training's rmse: 1.51149	valid_1's rmse: 1.54809
# [1300]	training's rmse: 1.50197	valid_1's rmse: 1.54192
# [1400]	training's rmse: 1.49329	valid_1's rmse: 1.53603
# [1500]	training's rmse: 1.48362	valid_1's rmse: 1.52918
# [1600]	training's rmse: 1.47663	valid_1's rmse: 1.52504
# [1700]	training's rmse: 1.46947	valid_1's rmse: 1.52029
# [1800]	training's rmse: 1.4625	valid_1's rmse: 1.51532
# [1900]	training's rmse: 1.45471	valid_1's rmse: 1.50964
# [2000]	training's rmse: 1.4486	valid_1's rmse: 1.50563
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.4486	valid_1's rmse: 1.50563
# KFold: 1 ==> RMSE: 1.5030
# KFold: 2 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32959	valid_1's rmse: 9.32908
# [200]	training's rmse: 3.79794	valid_1's rmse: 3.7877
# [300]	training's rmse: 2.13166	valid_1's rmse: 2.1115
# [400]	training's rmse: 1.76033	valid_1's rmse: 1.73961
# [500]	training's rmse: 1.66647	valid_1's rmse: 1.65146
# [600]	training's rmse: 1.62289	valid_1's rmse: 1.61577
# [700]	training's rmse: 1.59359	valid_1's rmse: 1.59456
# [800]	training's rmse: 1.56681	valid_1's rmse: 1.5759
# [900]	training's rmse: 1.54756	valid_1's rmse: 1.56407
# [1000]	training's rmse: 1.53319	valid_1's rmse: 1.55516
# [1100]	training's rmse: 1.51984	valid_1's rmse: 1.54649
# [1200]	training's rmse: 1.51054	valid_1's rmse: 1.54099
# [1300]	training's rmse: 1.50087	valid_1's rmse: 1.53485
# [1400]	training's rmse: 1.49081	valid_1's rmse: 1.52833
# [1500]	training's rmse: 1.48038	valid_1's rmse: 1.5214
# [1600]	training's rmse: 1.47296	valid_1's rmse: 1.51746
# [1700]	training's rmse: 1.46627	valid_1's rmse: 1.514
# [1800]	training's rmse: 1.45946	valid_1's rmse: 1.50989
# [1900]	training's rmse: 1.45329	valid_1's rmse: 1.50649
# [2000]	training's rmse: 1.44628	valid_1's rmse: 1.5025
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.44628	valid_1's rmse: 1.5025
# KFold: 2 ==> RMSE: 1.5030
# KFold: 3 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33024	valid_1's rmse: 9.32089
# [200]	training's rmse: 3.79219	valid_1's rmse: 3.80149
# [300]	training's rmse: 2.11949	valid_1's rmse: 2.14714
# [400]	training's rmse: 1.74609	valid_1's rmse: 1.7856
# [500]	training's rmse: 1.65395	valid_1's rmse: 1.70108
# [600]	training's rmse: 1.60992	valid_1's rmse: 1.66364
# [700]	training's rmse: 1.58111	valid_1's rmse: 1.64292
# [800]	training's rmse: 1.55659	valid_1's rmse: 1.62411
# [900]	training's rmse: 1.53925	valid_1's rmse: 1.61063
# [1000]	training's rmse: 1.52625	valid_1's rmse: 1.60183
# [1100]	training's rmse: 1.51521	valid_1's rmse: 1.59576
# [1200]	training's rmse: 1.50287	valid_1's rmse: 1.58674
# [1300]	training's rmse: 1.49153	valid_1's rmse: 1.57843
# [1400]	training's rmse: 1.48342	valid_1's rmse: 1.57344
# [1500]	training's rmse: 1.47463	valid_1's rmse: 1.56787
# [1600]	training's rmse: 1.46641	valid_1's rmse: 1.56227
# [1700]	training's rmse: 1.45963	valid_1's rmse: 1.55798
# [1800]	training's rmse: 1.45395	valid_1's rmse: 1.55471
# [1900]	training's rmse: 1.4487	valid_1's rmse: 1.55199
# [2000]	training's rmse: 1.44271	valid_1's rmse: 1.54847
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.44271	valid_1's rmse: 1.54847
# KFold: 3 ==> RMSE: 1.5072
# KFold: 4 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32726	valid_1's rmse: 9.33822
# [200]	training's rmse: 3.79507	valid_1's rmse: 3.80273
# [300]	training's rmse: 2.12582	valid_1's rmse: 2.13431
# [400]	training's rmse: 1.75113	valid_1's rmse: 1.76215
# [500]	training's rmse: 1.65695	valid_1's rmse: 1.67102
# [600]	training's rmse: 1.61451	valid_1's rmse: 1.63324
# [700]	training's rmse: 1.58569	valid_1's rmse: 1.61223
# [800]	training's rmse: 1.56167	valid_1's rmse: 1.59284
# [900]	training's rmse: 1.54259	valid_1's rmse: 1.57794
# [1000]	training's rmse: 1.53256	valid_1's rmse: 1.57058
# [1100]	training's rmse: 1.52287	valid_1's rmse: 1.56317
# [1200]	training's rmse: 1.51362	valid_1's rmse: 1.5567
# [1300]	training's rmse: 1.50454	valid_1's rmse: 1.54995
# [1400]	training's rmse: 1.49484	valid_1's rmse: 1.54244
# [1500]	training's rmse: 1.486	valid_1's rmse: 1.53577
# [1600]	training's rmse: 1.47815	valid_1's rmse: 1.52998
# [1700]	training's rmse: 1.46998	valid_1's rmse: 1.52383
# [1800]	training's rmse: 1.46164	valid_1's rmse: 1.5175
# [1900]	training's rmse: 1.45354	valid_1's rmse: 1.51145
# [2000]	training's rmse: 1.44656	valid_1's rmse: 1.5061
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.44656	valid_1's rmse: 1.5061
# KFold: 4 ==> RMSE: 1.5069
# KFold: 5 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32524	valid_1's rmse: 9.3376
# [200]	training's rmse: 3.78798	valid_1's rmse: 3.80964
# [300]	training's rmse: 2.11291	valid_1's rmse: 2.15597
# [400]	training's rmse: 1.73585	valid_1's rmse: 1.79744
# [500]	training's rmse: 1.63997	valid_1's rmse: 1.71138
# [600]	training's rmse: 1.59752	valid_1's rmse: 1.67569
# [700]	training's rmse: 1.5693	valid_1's rmse: 1.65367
# [800]	training's rmse: 1.5447	valid_1's rmse: 1.63588
# [900]	training's rmse: 1.52669	valid_1's rmse: 1.62224
# [1000]	training's rmse: 1.51285	valid_1's rmse: 1.61236
# [1100]	training's rmse: 1.50143	valid_1's rmse: 1.60416
# [1200]	training's rmse: 1.49246	valid_1's rmse: 1.59826
# [1300]	training's rmse: 1.48377	valid_1's rmse: 1.59256
# [1400]	training's rmse: 1.47658	valid_1's rmse: 1.58789
# [1500]	training's rmse: 1.46846	valid_1's rmse: 1.58222
# [1600]	training's rmse: 1.46094	valid_1's rmse: 1.57722
# [1700]	training's rmse: 1.45452	valid_1's rmse: 1.57302
# [1800]	training's rmse: 1.44857	valid_1's rmse: 1.56913
# [1900]	training's rmse: 1.44344	valid_1's rmse: 1.56584
# [2000]	training's rmse: 1.43788	valid_1's rmse: 1.56221
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.43788	valid_1's rmse: 1.56221
# KFold: 5 ==> RMSE: 1.5073
# Average RMSE: 1.5055 ± 0.0020
