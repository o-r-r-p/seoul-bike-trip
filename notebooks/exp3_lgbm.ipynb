# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')
import pickle

import lightgbm as lgb
import sys
from pathlib import Path

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering, feature_agg_temp

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()
test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
train = feature_engineering(train).to_pandas()
test = feature_engineering(test).to_pandas()

# %%
train, test = feature_agg_temp(train, test)

# %%
# データの準備
X, y = train.iloc[:, 1:], train["Duration"]
X_test = test.iloc[:, 1:]
y_test = test["Duration"]

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt', # LightGBMでは 'gbdt' が通常の勾配ブースティングを表す
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'lambda_l2': 0.2,
    'max_depth': 7,
    'num_leaves': 64, # LightGBM特有のパラメータ、ツリーの葉の数
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'verbose': -1 # verboseの設定は -1, 0, 1 となります
}

# KFoldの設定
kf = KFold(n_splits=5, shuffle=True, random_state=42)

del train, test

# %%
# Usage_timeを追加しての検証
rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # LightGBM用データセットの作成
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    print(f"KFold: {i+1} Start")
    
    # モデル学習
    model = lgb.train(params,
                      lgb_train,
                      num_boost_round=2000,
                      valid_sets=[lgb_train, lgb_val],
                      early_stopping_rounds=50,
                      verbose_eval=100
                     )
    
    # 推論
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/exp_lgbm/model_temp_2000_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32648	valid_1's rmse: 9.33321
# [200]	training's rmse: 3.79051	valid_1's rmse: 3.80118
# [300]	training's rmse: 2.11721	valid_1's rmse: 2.13766
# [400]	training's rmse: 1.74131	valid_1's rmse: 1.76813
# [500]	training's rmse: 1.64635	valid_1's rmse: 1.67777
# [600]	training's rmse: 1.60158	valid_1's rmse: 1.63676
# [700]	training's rmse: 1.57087	valid_1's rmse: 1.61159
# [800]	training's rmse: 1.54764	valid_1's rmse: 1.59343
# [900]	training's rmse: 1.52891	valid_1's rmse: 1.57744
# [1000]	training's rmse: 1.51603	valid_1's rmse: 1.56702
# [1100]	training's rmse: 1.5062	valid_1's rmse: 1.55984
# [1200]	training's rmse: 1.49518	valid_1's rmse: 1.55141
# [1300]	training's rmse: 1.48445	valid_1's rmse: 1.54287
# [1400]	training's rmse: 1.4748	valid_1's rmse: 1.53541
# [1500]	training's rmse: 1.46668	valid_1's rmse: 1.529
# [1600]	training's rmse: 1.45799	valid_1's rmse: 1.52266
# [1700]	training's rmse: 1.44992	valid_1's rmse: 1.5172
# [1800]	training's rmse: 1.44269	valid_1's rmse: 1.51238
# [1900]	training's rmse: 1.43612	valid_1's rmse: 1.50786
# [2000]	training's rmse: 1.42912	valid_1's rmse: 1.50303
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.42912	valid_1's rmse: 1.50303
# KFold: 1 ==> RMSE: 1.4827
# KFold: 2 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32886	valid_1's rmse: 9.326
# [200]	training's rmse: 3.79491	valid_1's rmse: 3.78809
# [300]	training's rmse: 2.125	valid_1's rmse: 2.11508
# [400]	training's rmse: 1.75251	valid_1's rmse: 1.74621
# [500]	training's rmse: 1.65846	valid_1's rmse: 1.65861
# [600]	training's rmse: 1.61269	valid_1's rmse: 1.62044
# [700]	training's rmse: 1.58537	valid_1's rmse: 1.60219
# [800]	training's rmse: 1.56127	valid_1's rmse: 1.58471
# [900]	training's rmse: 1.54071	valid_1's rmse: 1.56921
# [1000]	training's rmse: 1.52598	valid_1's rmse: 1.55901
# [1100]	training's rmse: 1.51266	valid_1's rmse: 1.55055
# [1200]	training's rmse: 1.50233	valid_1's rmse: 1.54491
# [1300]	training's rmse: 1.49316	valid_1's rmse: 1.53917
# [1400]	training's rmse: 1.48449	valid_1's rmse: 1.53337
# [1500]	training's rmse: 1.4739	valid_1's rmse: 1.52618
# [1600]	training's rmse: 1.46398	valid_1's rmse: 1.51989
# [1700]	training's rmse: 1.45583	valid_1's rmse: 1.51504
# [1800]	training's rmse: 1.44771	valid_1's rmse: 1.50967
# [1900]	training's rmse: 1.44101	valid_1's rmse: 1.50564
# [2000]	training's rmse: 1.43399	valid_1's rmse: 1.50086
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.43399	valid_1's rmse: 1.50086
# KFold: 2 ==> RMSE: 1.4886
# KFold: 3 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.3296	valid_1's rmse: 9.32666
# [200]	training's rmse: 3.79516	valid_1's rmse: 3.78786
# [300]	training's rmse: 2.12535	valid_1's rmse: 2.11369
# [400]	training's rmse: 1.75033	valid_1's rmse: 1.74205
# [500]	training's rmse: 1.65629	valid_1's rmse: 1.65406
# [600]	training's rmse: 1.61179	valid_1's rmse: 1.61616
# [700]	training's rmse: 1.58051	valid_1's rmse: 1.593
# [800]	training's rmse: 1.55624	valid_1's rmse: 1.57467
# [900]	training's rmse: 1.53767	valid_1's rmse: 1.56095
# [1000]	training's rmse: 1.52705	valid_1's rmse: 1.55341
# [1100]	training's rmse: 1.51694	valid_1's rmse: 1.54673
# [1200]	training's rmse: 1.50666	valid_1's rmse: 1.53975
# [1300]	training's rmse: 1.49731	valid_1's rmse: 1.53363
# [1400]	training's rmse: 1.48713	valid_1's rmse: 1.52674
# [1500]	training's rmse: 1.47815	valid_1's rmse: 1.52048
# [1600]	training's rmse: 1.46872	valid_1's rmse: 1.51414
# [1700]	training's rmse: 1.46119	valid_1's rmse: 1.50919
# [1800]	training's rmse: 1.4522	valid_1's rmse: 1.50326
# [1900]	training's rmse: 1.4447	valid_1's rmse: 1.49843
# [2000]	training's rmse: 1.43756	valid_1's rmse: 1.49341
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.43756	valid_1's rmse: 1.49341
# KFold: 3 ==> RMSE: 1.4927
# KFold: 4 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.3271	valid_1's rmse: 9.33515
# [200]	training's rmse: 3.79264	valid_1's rmse: 3.80467
# [300]	training's rmse: 2.11985	valid_1's rmse: 2.14494
# [400]	training's rmse: 1.74521	valid_1's rmse: 1.7816
# [500]	training's rmse: 1.6515	valid_1's rmse: 1.69559
# [600]	training's rmse: 1.60542	valid_1's rmse: 1.65524
# [700]	training's rmse: 1.57701	valid_1's rmse: 1.63494
# [800]	training's rmse: 1.55353	valid_1's rmse: 1.6186
# [900]	training's rmse: 1.53306	valid_1's rmse: 1.60433
# [1000]	training's rmse: 1.51832	valid_1's rmse: 1.59402
# [1100]	training's rmse: 1.50648	valid_1's rmse: 1.58627
# [1200]	training's rmse: 1.49543	valid_1's rmse: 1.57874
# [1300]	training's rmse: 1.48669	valid_1's rmse: 1.57342
# [1400]	training's rmse: 1.47667	valid_1's rmse: 1.56688
# [1500]	training's rmse: 1.4663	valid_1's rmse: 1.55967
# [1600]	training's rmse: 1.45671	valid_1's rmse: 1.55317
# [1700]	training's rmse: 1.44824	valid_1's rmse: 1.5472
# [1800]	training's rmse: 1.44053	valid_1's rmse: 1.54206
# [1900]	training's rmse: 1.43321	valid_1's rmse: 1.53718
# [2000]	training's rmse: 1.42619	valid_1's rmse: 1.5328
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.42619	valid_1's rmse: 1.5328
# KFold: 4 ==> RMSE: 1.5029
# KFold: 5 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32937	valid_1's rmse: 9.32359
# [200]	training's rmse: 3.79299	valid_1's rmse: 3.7995
# [300]	training's rmse: 2.12194	valid_1's rmse: 2.14038
# [400]	training's rmse: 1.74746	valid_1's rmse: 1.77371
# [500]	training's rmse: 1.65494	valid_1's rmse: 1.68764
# [600]	training's rmse: 1.61085	valid_1's rmse: 1.64871
# [700]	training's rmse: 1.58114	valid_1's rmse: 1.62701
# [800]	training's rmse: 1.55522	valid_1's rmse: 1.6074
# [900]	training's rmse: 1.53495	valid_1's rmse: 1.59122
# [1000]	training's rmse: 1.51951	valid_1's rmse: 1.58059
# [1100]	training's rmse: 1.50679	valid_1's rmse: 1.57176
# [1200]	training's rmse: 1.49816	valid_1's rmse: 1.56581
# [1300]	training's rmse: 1.4879	valid_1's rmse: 1.55841
# [1400]	training's rmse: 1.47874	valid_1's rmse: 1.55203
# [1500]	training's rmse: 1.46933	valid_1's rmse: 1.54603
# [1600]	training's rmse: 1.46066	valid_1's rmse: 1.54073
# [1700]	training's rmse: 1.45277	valid_1's rmse: 1.53545
# [1800]	training's rmse: 1.44512	valid_1's rmse: 1.53059
# [1900]	training's rmse: 1.43921	valid_1's rmse: 1.52679
# [2000]	training's rmse: 1.43217	valid_1's rmse: 1.52203
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.43217	valid_1's rmse: 1.52203
# KFold: 5 ==> RMSE: 1.4893
# Average RMSE: 1.4912 ± 0.0067

# %% [markdown]
# ## Note
# - exp2: Average RMSE: 1.5055 ± 0.0020
# - 精度は0.01くらい改善、バラつきが大きくなった
# - 位置情報の特徴量を加えてみる
