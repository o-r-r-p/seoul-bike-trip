# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')
import pickle

import lightgbm as lgb
import sys
from pathlib import Path

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering, feature_agg_temp

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()
test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
train = feature_engineering(train).to_pandas()
test = feature_engineering(test).to_pandas()

# %%
train, test = feature_agg_temp(train, test)

# %%
train.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0        28      8480  37.530167  127.007439  37.535221  127.068398
# 1        11      2130  37.544582  127.044609  37.542580  127.063309
# 2        93     10240  37.557892  126.938080  37.547733  126.931763
# 3        18      3320  37.526066  126.925537  37.543579  126.951324
# 4       113      8220  37.471539  127.050591  37.505581  127.024277
#
#    Haversine  Pmonth  Pday  Phour  ...  Humid  Solar  Snow  GroundTemp  Dust  \
# 0   5.404561       4    14     19  ...   76.0   0.02   0.0         9.9  13.0
# 1   1.663655       4    17     19  ...   31.0   0.25   0.0        13.2  91.0
# 2   1.259433       4     1     19  ...   79.0   0.03   0.0        15.9  74.0
# 3   2.993715       4    29     19  ...   38.0   0.16   0.0        17.4  52.0
# 4   4.440585       4    12     19  ...   14.0   0.25   0.0        11.9  28.0
#
#    Usage_time    Velocity  Temp_max  Temp_min  Temp_mean
# 0          28  302.857143      22.9       2.5  16.548405
# 1          11  193.636364      22.9       2.5  16.548405
# 2          94  108.936170      22.9       2.5  16.548405
# 3          19  174.736842      22.9       2.5  16.548405
# 4         123   66.829268      22.9       2.5  16.548405
#
# [5 rows x 30 columns]

# %%
# データの準備
X, y = train.iloc[:, 1:], train["Duration"]
X_test = test.iloc[:, 1:]
y_test = test["Duration"]

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt', # LightGBMでは 'gbdt' が通常の勾配ブースティングを表す
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'lambda_l2': 0.2,
    'max_depth': 7,
    'num_leaves': 64, # LightGBM特有のパラメータ、ツリーの葉の数
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'verbose': -1 # verboseの設定は -1, 0, 1 となります
}

# KFoldの設定
kf = KFold(n_splits=5, shuffle=True, random_state=42)

del train, test

# %%
# Usage_timeを追加しての検証
rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # LightGBM用データセットの作成
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    print(f"KFold: {i+1} Start")
    
    # モデル学習
    model = lgb.train(params,
                      lgb_train,
                      num_boost_round=2000,
                      valid_sets=[lgb_train, lgb_val],
                      early_stopping_rounds=50,
                      verbose_eval=100
                     )
    
    # 推論
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/exp_lgbm/model_velocity_2000_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.3303	valid_1's rmse: 9.33753
# [200]	training's rmse: 3.79474	valid_1's rmse: 3.80598
# [300]	training's rmse: 2.12496	valid_1's rmse: 2.1464
# [400]	training's rmse: 1.7499	valid_1's rmse: 1.77836
# [500]	training's rmse: 1.65585	valid_1's rmse: 1.68794
# [600]	training's rmse: 1.61235	valid_1's rmse: 1.64813
# [700]	training's rmse: 1.5747	valid_1's rmse: 1.61695
# [800]	training's rmse: 1.5466	valid_1's rmse: 1.59322
# [900]	training's rmse: 1.52592	valid_1's rmse: 1.5757
# [1000]	training's rmse: 1.51056	valid_1's rmse: 1.56402
# [1100]	training's rmse: 1.49757	valid_1's rmse: 1.55374
# [1200]	training's rmse: 1.48599	valid_1's rmse: 1.5454
# [1300]	training's rmse: 1.4753	valid_1's rmse: 1.53733
# [1400]	training's rmse: 1.4608	valid_1's rmse: 1.5252
# [1500]	training's rmse: 1.44935	valid_1's rmse: 1.51642
# [1600]	training's rmse: 1.43888	valid_1's rmse: 1.50766
# [1700]	training's rmse: 1.43181	valid_1's rmse: 1.50196
# [1800]	training's rmse: 1.42538	valid_1's rmse: 1.49708
# [1900]	training's rmse: 1.41892	valid_1's rmse: 1.4924
# [2000]	training's rmse: 1.41226	valid_1's rmse: 1.48799
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.41226	valid_1's rmse: 1.48799
# KFold: 1 ==> RMSE: 1.4679
# KFold: 2 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33357	valid_1's rmse: 9.33043
# [200]	training's rmse: 3.79868	valid_1's rmse: 3.79209
# [300]	training's rmse: 2.12974	valid_1's rmse: 2.12111
# [400]	training's rmse: 1.75697	valid_1's rmse: 1.75133
# [500]	training's rmse: 1.66921	valid_1's rmse: 1.66971
# [600]	training's rmse: 1.62485	valid_1's rmse: 1.63358
# [700]	training's rmse: 1.59138	valid_1's rmse: 1.60796
# [800]	training's rmse: 1.56195	valid_1's rmse: 1.58523
# [900]	training's rmse: 1.54049	valid_1's rmse: 1.56876
# [1000]	training's rmse: 1.52298	valid_1's rmse: 1.55664
# [1100]	training's rmse: 1.50685	valid_1's rmse: 1.5455
# [1200]	training's rmse: 1.49392	valid_1's rmse: 1.53668
# [1300]	training's rmse: 1.48361	valid_1's rmse: 1.52999
# [1400]	training's rmse: 1.47462	valid_1's rmse: 1.52484
# [1500]	training's rmse: 1.46616	valid_1's rmse: 1.5197
# [1600]	training's rmse: 1.45773	valid_1's rmse: 1.51463
# [1700]	training's rmse: 1.45	valid_1's rmse: 1.50994
# [1800]	training's rmse: 1.44278	valid_1's rmse: 1.50559
# [1900]	training's rmse: 1.43597	valid_1's rmse: 1.50117
# [2000]	training's rmse: 1.429	valid_1's rmse: 1.49665
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.429	valid_1's rmse: 1.49665
# KFold: 2 ==> RMSE: 1.4857
# KFold: 3 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33385	valid_1's rmse: 9.33078
# [200]	training's rmse: 3.80019	valid_1's rmse: 3.79289
# [300]	training's rmse: 2.13327	valid_1's rmse: 2.12182
# [400]	training's rmse: 1.75835	valid_1's rmse: 1.75032
# [500]	training's rmse: 1.66244	valid_1's rmse: 1.66113
# [600]	training's rmse: 1.61811	valid_1's rmse: 1.62283
# [700]	training's rmse: 1.57812	valid_1's rmse: 1.59034
# [800]	training's rmse: 1.55067	valid_1's rmse: 1.5687
# [900]	training's rmse: 1.5329	valid_1's rmse: 1.55602
# [1000]	training's rmse: 1.52067	valid_1's rmse: 1.54767
# [1100]	training's rmse: 1.50673	valid_1's rmse: 1.53741
# [1200]	training's rmse: 1.49527	valid_1's rmse: 1.52895
# [1300]	training's rmse: 1.4833	valid_1's rmse: 1.52046
# [1400]	training's rmse: 1.47329	valid_1's rmse: 1.5137
# [1500]	training's rmse: 1.46372	valid_1's rmse: 1.50725
# [1600]	training's rmse: 1.4559	valid_1's rmse: 1.50221
# [1700]	training's rmse: 1.44808	valid_1's rmse: 1.49684
# [1800]	training's rmse: 1.44166	valid_1's rmse: 1.49253
# [1900]	training's rmse: 1.43478	valid_1's rmse: 1.48788
# [2000]	training's rmse: 1.42746	valid_1's rmse: 1.48296
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.42746	valid_1's rmse: 1.48296
# KFold: 3 ==> RMSE: 1.4832
# KFold: 4 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33187	valid_1's rmse: 9.34007
# [200]	training's rmse: 3.79746	valid_1's rmse: 3.81067
# [300]	training's rmse: 2.12857	valid_1's rmse: 2.15487
# [400]	training's rmse: 1.75212	valid_1's rmse: 1.79001
# [500]	training's rmse: 1.65722	valid_1's rmse: 1.70265
# [600]	training's rmse: 1.61263	valid_1's rmse: 1.66305
# [700]	training's rmse: 1.57752	valid_1's rmse: 1.63559
# [800]	training's rmse: 1.55025	valid_1's rmse: 1.61382
# [900]	training's rmse: 1.53	valid_1's rmse: 1.59879
# [1000]	training's rmse: 1.51335	valid_1's rmse: 1.58665
# [1100]	training's rmse: 1.4994	valid_1's rmse: 1.57629
# [1200]	training's rmse: 1.48699	valid_1's rmse: 1.5673
# [1300]	training's rmse: 1.473	valid_1's rmse: 1.55718
# [1400]	training's rmse: 1.46175	valid_1's rmse: 1.54908
# [1500]	training's rmse: 1.45285	valid_1's rmse: 1.54329
# [1600]	training's rmse: 1.44502	valid_1's rmse: 1.53855
# [1700]	training's rmse: 1.43687	valid_1's rmse: 1.53329
# [1800]	training's rmse: 1.42841	valid_1's rmse: 1.52784
# [1900]	training's rmse: 1.4212	valid_1's rmse: 1.52383
# [2000]	training's rmse: 1.41349	valid_1's rmse: 1.51909
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.41349	valid_1's rmse: 1.51909
# KFold: 4 ==> RMSE: 1.4911
# KFold: 5 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33359	valid_1's rmse: 9.32838
# [200]	training's rmse: 3.79665	valid_1's rmse: 3.80418
# [300]	training's rmse: 2.12683	valid_1's rmse: 2.1462
# [400]	training's rmse: 1.75168	valid_1's rmse: 1.77972
# [500]	training's rmse: 1.65979	valid_1's rmse: 1.69439
# [600]	training's rmse: 1.61506	valid_1's rmse: 1.65479
# [700]	training's rmse: 1.57878	valid_1's rmse: 1.62612
# [800]	training's rmse: 1.55132	valid_1's rmse: 1.60498
# [900]	training's rmse: 1.52659	valid_1's rmse: 1.58437
# [1000]	training's rmse: 1.51045	valid_1's rmse: 1.57138
# [1100]	training's rmse: 1.49748	valid_1's rmse: 1.56184
# [1200]	training's rmse: 1.48658	valid_1's rmse: 1.55348
# [1300]	training's rmse: 1.47759	valid_1's rmse: 1.54657
# [1400]	training's rmse: 1.46825	valid_1's rmse: 1.53974
# [1500]	training's rmse: 1.45944	valid_1's rmse: 1.53393
# [1600]	training's rmse: 1.45061	valid_1's rmse: 1.52831
# [1700]	training's rmse: 1.44342	valid_1's rmse: 1.52372
# [1800]	training's rmse: 1.43597	valid_1's rmse: 1.51824
# [1900]	training's rmse: 1.42844	valid_1's rmse: 1.51279
# [2000]	training's rmse: 1.42152	valid_1's rmse: 1.50817
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.42152	valid_1's rmse: 1.50817
# KFold: 5 ==> RMSE: 1.4800
# Average RMSE: 1.4816 ± 0.0077

# %% [markdown]
# ## Note
# - exp2: Average RMSE: 1.5055 ± 0.0020
# - 精度は0.01くらい改善、バラつきが大きくなった
# - 位置情報の特徴量を加えてみる
