# %%
import gc
import pandas as pd
import polars as pl
import numpy as np
import datetime as dt

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')
import pickle

import lightgbm as lgb
import sys
from pathlib import Path

# スクリプトのあるディレクトリの絶対パスを取得
script_dir = str(Path('../scripts').resolve())

# sys.pathにスクリプトのディレクトリを追加
if script_dir not in sys.path:
    sys.path.insert(0, script_dir)

from preprocess import reduce_mem_usage, feature_engineering, feature_agg_temp

# %%
train = reduce_mem_usage(pl.scan_parquet("../data/train.parquet")).collect()
test = reduce_mem_usage(pl.scan_parquet("../data/test.parquet")).collect()

# %%
train = feature_engineering(train).to_pandas()
test = feature_engineering(test).to_pandas()

# %%
train, test = feature_agg_temp(train, test)

# %%
train.head()
# Out:
#    Duration  Distance      PLong       PLatd      DLong       DLatd  \
# 0        28      8480  37.530167  127.007439  37.535221  127.068398
# 1        51      7710  37.530167  127.007439  37.535221  127.068398
# 2        59      8020  37.530167  127.007439  37.535221  127.068398
# 3        53     10490  37.530167  127.007439  37.535221  127.068398
# 4        24      7230  37.530167  127.007439  37.535221  127.068398
#
#    Haversine  Pmonth  Pday  Phour  ...  Snow  GroundTemp  Dust  Usage_time  \
# 0   5.404561       4    14     19  ...   0.0         9.9  13.0          28
# 1   5.404561       9    12     18  ...   0.0        28.5  17.0          51
# 2   5.404561       6    30     22  ...   0.0        22.4   0.0          60
# 3   5.404561       7    25     22  ...   0.0        28.1  27.0          55
# 4   5.404561      11    30     20  ...   0.0        -0.4  50.0          26
#
#      Velocity  Temp_max  Temp_min  Temp_mean  Duration_meadian  Duratioin_mean
# 0  302.857143      22.9       2.5  16.548405              51.0            43.0
# 1  151.176471      28.8      18.3  24.362245              51.0            43.0
# 2  133.666667      27.4      19.0  22.198692              51.0            43.0
# 3  190.727273      32.5      20.4  27.672861              51.0            43.0
# 4  278.076923      13.9       2.6   8.890479              51.0            43.0
#
# [5 rows x 32 columns]

# %%
# データの準備
X, y = train.iloc[:, 1:], train["Duration"]
X_test = test.iloc[:, 1:]
y_test = test["Duration"]

# LightGBMのパラメータ設定
params = {
    'boosting_type': 'gbdt', # LightGBMでは 'gbdt' が通常の勾配ブースティングを表す
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'lambda_l2': 0.2,
    'max_depth': 7,
    'num_leaves': 64, # LightGBM特有のパラメータ、ツリーの葉の数
    'min_child_weight': 1,
    'subsample': 1,
    'colsample_bytree': 1,
    'verbose': -1 # verboseの設定は -1, 0, 1 となります
}

# KFoldの設定
kf = KFold(n_splits=4, shuffle=True, random_state=42)

del train, test

# %%
# Usage_timeを追加しての検証
rmse = []
for i, (train_index, val_index) in enumerate(kf.split(X)):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]
    
    # LightGBM用データセットの作成
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)
    
    print(f"KFold: {i+1} Start")
    
    # モデル学習
    model = lgb.train(params,
                      lgb_train,
                      num_boost_round=2000,
                      valid_sets=[lgb_train, lgb_val],
                      early_stopping_rounds=50,
                      verbose_eval=100
                     )
    
    # 推論
    y_pred = model.predict(X_test, num_iteration=model.best_iteration)

    score = np.sqrt(mean_squared_error(y_test, y_pred))
    rmse.append(score)
    print(f"KFold: {i+1} ==> RMSE: {score:.4f}")
    with open(f"./models/exp_lgbm/model_velocity_2000_{i+1}.pickle", mode='wb') as f:
        pickle.dump(model, f)

print(f"Average RMSE: {np.mean(rmse):.4f} ± {np.std(rmse):.4f}")
# Out:
# KFold: 1 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33043	valid_1's rmse: 9.32229
# [200]	training's rmse: 3.78801	valid_1's rmse: 3.78736
# [300]	training's rmse: 2.104	valid_1's rmse: 2.1109
# [400]	training's rmse: 1.72328	valid_1's rmse: 1.73699
# [500]	training's rmse: 1.63153	valid_1's rmse: 1.64985
# [600]	training's rmse: 1.58636	valid_1's rmse: 1.60925
# [700]	training's rmse: 1.55004	valid_1's rmse: 1.57954
# [800]	training's rmse: 1.52055	valid_1's rmse: 1.55492
# [900]	training's rmse: 1.50231	valid_1's rmse: 1.5404
# [1000]	training's rmse: 1.48905	valid_1's rmse: 1.53102
# [1100]	training's rmse: 1.47799	valid_1's rmse: 1.52329
# [1200]	training's rmse: 1.46797	valid_1's rmse: 1.51655
# [1300]	training's rmse: 1.45669	valid_1's rmse: 1.50828
# [1400]	training's rmse: 1.44507	valid_1's rmse: 1.49933
# [1500]	training's rmse: 1.43534	valid_1's rmse: 1.49186
# [1600]	training's rmse: 1.42673	valid_1's rmse: 1.48596
# [1700]	training's rmse: 1.41958	valid_1's rmse: 1.48154
# [1800]	training's rmse: 1.41152	valid_1's rmse: 1.47605
# [1900]	training's rmse: 1.40516	valid_1's rmse: 1.47243
# [2000]	training's rmse: 1.39848	valid_1's rmse: 1.46814
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.39848	valid_1's rmse: 1.46814
# KFold: 1 ==> RMSE: 1.4600
# KFold: 2 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32675	valid_1's rmse: 9.33411
# [200]	training's rmse: 3.7858	valid_1's rmse: 3.78777
# [300]	training's rmse: 2.10121	valid_1's rmse: 2.1054
# [400]	training's rmse: 1.71921	valid_1's rmse: 1.72988
# [500]	training's rmse: 1.62455	valid_1's rmse: 1.64141
# [600]	training's rmse: 1.57857	valid_1's rmse: 1.60014
# [700]	training's rmse: 1.5441	valid_1's rmse: 1.57364
# [800]	training's rmse: 1.51596	valid_1's rmse: 1.55202
# [900]	training's rmse: 1.50029	valid_1's rmse: 1.54066
# [1000]	training's rmse: 1.4878	valid_1's rmse: 1.53206
# [1100]	training's rmse: 1.47855	valid_1's rmse: 1.52634
# [1200]	training's rmse: 1.46881	valid_1's rmse: 1.51988
# [1300]	training's rmse: 1.45735	valid_1's rmse: 1.51267
# [1400]	training's rmse: 1.44756	valid_1's rmse: 1.50585
# [1500]	training's rmse: 1.4378	valid_1's rmse: 1.49964
# [1600]	training's rmse: 1.43085	valid_1's rmse: 1.49546
# [1700]	training's rmse: 1.42255	valid_1's rmse: 1.49014
# [1800]	training's rmse: 1.41567	valid_1's rmse: 1.48581
# [1900]	training's rmse: 1.40936	valid_1's rmse: 1.48233
# [2000]	training's rmse: 1.40403	valid_1's rmse: 1.479
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.40403	valid_1's rmse: 1.479
# KFold: 2 ==> RMSE: 1.4661
# KFold: 3 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.33048	valid_1's rmse: 9.32575
# [200]	training's rmse: 3.78792	valid_1's rmse: 3.78943
# [300]	training's rmse: 2.10531	valid_1's rmse: 2.11298
# [400]	training's rmse: 1.72338	valid_1's rmse: 1.73899
# [500]	training's rmse: 1.62872	valid_1's rmse: 1.65164
# [600]	training's rmse: 1.58283	valid_1's rmse: 1.61261
# [700]	training's rmse: 1.54884	valid_1's rmse: 1.58636
# [800]	training's rmse: 1.52192	valid_1's rmse: 1.56539
# [900]	training's rmse: 1.5021	valid_1's rmse: 1.55025
# [1000]	training's rmse: 1.48928	valid_1's rmse: 1.54093
# [1100]	training's rmse: 1.47698	valid_1's rmse: 1.53155
# [1200]	training's rmse: 1.46606	valid_1's rmse: 1.5243
# [1300]	training's rmse: 1.45434	valid_1's rmse: 1.5162
# [1400]	training's rmse: 1.44231	valid_1's rmse: 1.50749
# [1500]	training's rmse: 1.43247	valid_1's rmse: 1.50071
# [1600]	training's rmse: 1.42454	valid_1's rmse: 1.49518
# [1700]	training's rmse: 1.41738	valid_1's rmse: 1.49073
# [1800]	training's rmse: 1.40948	valid_1's rmse: 1.48585
# [1900]	training's rmse: 1.40268	valid_1's rmse: 1.48174
# [2000]	training's rmse: 1.39592	valid_1's rmse: 1.47794
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.39592	valid_1's rmse: 1.47794
# KFold: 3 ==> RMSE: 1.4635
# KFold: 4 Start
# Training until validation scores don't improve for 50 rounds
# [100]	training's rmse: 9.32669	valid_1's rmse: 9.33491
# [200]	training's rmse: 3.78359	valid_1's rmse: 3.79471
# [300]	training's rmse: 2.09828	valid_1's rmse: 2.11788
# [400]	training's rmse: 1.71852	valid_1's rmse: 1.74492
# [500]	training's rmse: 1.62398	valid_1's rmse: 1.65646
# [600]	training's rmse: 1.57896	valid_1's rmse: 1.61663
# [700]	training's rmse: 1.54497	valid_1's rmse: 1.58904
# [800]	training's rmse: 1.51897	valid_1's rmse: 1.57005
# [900]	training's rmse: 1.50081	valid_1's rmse: 1.55649
# [1000]	training's rmse: 1.48746	valid_1's rmse: 1.54736
# [1100]	training's rmse: 1.47435	valid_1's rmse: 1.53769
# [1200]	training's rmse: 1.46326	valid_1's rmse: 1.52967
# [1300]	training's rmse: 1.45164	valid_1's rmse: 1.52088
# [1400]	training's rmse: 1.44156	valid_1's rmse: 1.51343
# [1500]	training's rmse: 1.43132	valid_1's rmse: 1.50575
# [1600]	training's rmse: 1.42287	valid_1's rmse: 1.49957
# [1700]	training's rmse: 1.41582	valid_1's rmse: 1.49487
# [1800]	training's rmse: 1.40856	valid_1's rmse: 1.48989
# [1900]	training's rmse: 1.40193	valid_1's rmse: 1.48557
# [2000]	training's rmse: 1.39391	valid_1's rmse: 1.48008
# Did not meet early stopping. Best iteration is:
# [2000]	training's rmse: 1.39391	valid_1's rmse: 1.48008
# KFold: 4 ==> RMSE: 1.4579
# Average RMSE: 1.4619 ± 0.0032

# %% [markdown]
# ## Note
# - 学習：検証の比率は変えてみたが、3:1で問題なさそう
